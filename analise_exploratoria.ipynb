# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
#upload do arquivo
from google.colab import files
arq = files.upload()
# Out:
#      <input type="file" id="files-f516eb94-43e5-4ab5-9cef-5b214a665fd4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f516eb94-43e5-4ab5-9cef-5b214a665fd4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving AdventureWorks.xlsx to AdventureWorks.xlsx

# %%
#Criando DataFrame
df = pd.read_excel('AdventureWorks.xlsx')

# %%
df.head()
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
# 1 2008-05-12 2008-05-17      306         384       19051  200805123CS567
# 2 2008-05-14 2008-05-20      306         384       19052  200805143CS576
# 3 2008-05-21 2008-05-27      306         384       19052  200805213CS576
# 4 2008-06-20 2008-06-27      306         384       19053  200806203CS586
#
#    Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  Valor Venda  \
# 0          348.58           758.0           6             0.0       4548.0
# 1          348.58           758.0           6             0.0       4548.0
# 2          348.58           758.0           6             0.0       4548.0
# 3          348.58           758.0           6             0.0       4548.0
# 4          348.58           758.0           6             0.0       4548.0
#
# ...

# %%
df.dtypes
# Out:
# Data Venda        datetime64[ns]
# Data Envio        datetime64[ns]
# ID Loja                    int64
# ID Produto                 int64
# ID Cliente                 int64
# No. Venda                 object
# Custo Unitário           float64
# Preço Unitário           float64
# Quantidade                 int64
# Valor Desconto           float64
# Valor Venda              float64
# Produto                   object
# Fabricante                object
# Marca                     object
# Classe                    object
# Cor                       object
# dtype: object

# %%
df.shape
# Out:
# (904, 16)

# %%
#Qual a receita total ?
df['Valor Venda'].sum()
# Out:
# 5984606.1426

# %%
#Qual o custo total ?
df['Custo'] = df['Custo Unitário'].mul(df['Quantidade']) #Criando a coluna custo

# %%
df.head(5)
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
# 1 2008-05-12 2008-05-17      306         384       19051  200805123CS567
# 2 2008-05-14 2008-05-20      306         384       19052  200805143CS576
# 3 2008-05-21 2008-05-27      306         384       19052  200805213CS576
# 4 2008-06-20 2008-06-27      306         384       19053  200806203CS586
#
#    Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  Valor Venda  \
# 0          348.58           758.0           6             0.0       4548.0
# 1          348.58           758.0           6             0.0       4548.0
# 2          348.58           758.0           6             0.0       4548.0
# 3          348.58           758.0           6             0.0       4548.0
# 4          348.58           758.0           6             0.0       4548.0
#
# ...

# %%
#Qual o custo total ?
round(df['Custo']).sum()
# Out:
# 2486755.0

# %%
#Agora que temos a receita, custo e o total, podemos achar o Lucro total
#Vamos criar uma coluna de Lucro que será Receita - Custo
df['Lucro'] = df['Valor Venda'] - df['Custo']

# %%
df.head(1)
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
#
#    Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  Valor Venda  \
# 0          348.58           758.0           6             0.0       4548.0
#
#                                  Produto       Fabricante            Marca  \
# 0  Adventure Works Laptop15.4W M1548 Red  Adventure Works  Adventure Works
#
#     Classe  Cor    Custo    Lucro
# 0  Regular  Red  2091.48  2456.52

# %%
#Total de Lucro - Arredondando para duas casa decimais
round(df['Lucro'].sum(),2)
# Out:
# 3497823.09

# %%
df.shape
# Out:
# (904, 19)

# %%
#Criando uma coluna com total de dias para enviar o produto
df['Tempo Medio'] = df['Data Envio'] - df['Data Venda']

# %%
df.head(1)
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
#
#    Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  Valor Venda  \
# 0          348.58           758.0           6             0.0       4548.0
#
#                                  Produto       Fabricante            Marca  \
# 0  Adventure Works Laptop15.4W M1548 Red  Adventure Works  Adventure Works
#
#     Classe  Cor    Custo    Lucro Tempo Medio
# 0  Regular  Red  2091.48  2456.52     20 days

# %% [markdown]
# Agora queremos saber a média do tempo de envio para cada Marca, e para isso precisamos tranformar a coluna Tempo_envio em númerica

# %%
#Extraindo apenas os dias
df['Tempo_envio'] = (df['Data Envio'] - df['Data Venda']).dt.days

# %%
df.head(5)
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
# 1 2008-05-12 2008-05-17      306         384       19051  200805123CS567
# 2 2008-05-14 2008-05-20      306         384       19052  200805143CS576
# 3 2008-05-21 2008-05-27      306         384       19052  200805213CS576
# 4 2008-06-20 2008-06-27      306         384       19053  200806203CS586
#
#    Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  Valor Venda  \
# 0          348.58           758.0           6             0.0       4548.0
# 1          348.58           758.0           6             0.0       4548.0
# 2          348.58           758.0           6             0.0       4548.0
# 3          348.58           758.0           6             0.0       4548.0
# 4          348.58           758.0           6             0.0       4548.0
#
# ...

# %%
#Verificando o tipo da coluna Tempo_envio
df['Tempo_envio'].dtype
# Out:
# dtype('int64')

# %%
#Média do tempo de envio por Marca
df.groupby('Marca')['Tempo_envio'].mean()
# Out:
# Marca
# Adventure Works    8.663866
# Contoso            8.470930
# Fabrikam           8.510121
# Name: Tempo_envio, dtype: float64

# %% [markdown]
# Missing Values

# %%
#Verificando se temos dados faltantes
df.isnull().sum()
# Out:
# Data Venda        0
# Data Envio        0
# ID Loja           0
# ID Produto        0
# ID Cliente        0
# No. Venda         0
# Custo Unitário    0
# Preço Unitário    0
# Quantidade        0
# Valor Desconto    0
# Valor Venda       0
# Produto           0
# Fabricante        0
# Marca             0
# Classe            0
# Cor               0
# Custo             0
# Lucro             0
# Tempo Medio       0
# Tempo_envio       0
# dtype: int64

# %% [markdown]
# E, se a gente quiser saber o Lucro por Ano e por Marca

# %%
#Vamos agrupar por ano e marca
df.groupby([df['Data Venda'].dt.year, 'Marca'])['Lucro'].sum()
# Out:
# Data Venda  Marca
# 2008        Adventure Works             306,641.16
#             Contoso                      56,416.00
#             Fabrikam                  1,557,020.55
# 2009        Adventure Works             405,395.08
#             Contoso                     138,258.95
#             Fabrikam                  1,034,091.35
# Name: Lucro, dtype: float64

# %%
pd.options.display.float_format = '{:20,.2f}'.format

# %%
#Resetando o index
lucro_ano = df.groupby([df['Data Venda'].dt.year, 'Marca'])['Lucro'].sum().reset_index()
lucro_ano
# Out:
#    Data Venda            Marca                Lucro
# 0        2008  Adventure Works           306,641.16
# 1        2008          Contoso            56,416.00
# 2        2008         Fabrikam         1,557,020.55
# 3        2009  Adventure Works           405,395.08
# 4        2009          Contoso           138,258.95
# 5        2009         Fabrikam         1,034,091.35

# %%
#Qual o total de produtos vendidos ?
df.groupby('Produto')['Quantidade'].sum().sort_values(ascending=False)
# Out:
# Produto
# Headphone Adapter for Contoso Phone E130 Silver    25232
# Headphone Adapter for Contoso Phone E130 White     25008
# Adventure Works Laptop15.4W M1548 Black             1089
# Fabrikam Trendsetter 2/3'' 17mm X100 Grey           1087
# Adventure Works Laptop15.4W M1548 Red               1047
# Fabrikam Trendsetter 2/3'' 17mm X100 Black           926
# Fabrikam Trendsetter 1/3'' 8.5mm X200 Black          884
# Fabrikam Trendsetter 1/3'' 8.5mm X200 Grey           845
# Fabrikam Trendsetter 1/3'' 8.5mm X200 White          789
# Name: Quantidade, dtype: int64

# %%
#Grafico Total de produtos vendidos 
df.groupby('Produto')['Quantidade'].sum().sort_values(ascending=True).plot.barh(title='Total Produtos Vendidos');

# %%
#Lucro por ano
df.groupby(df['Data Venda'].dt.year)['Lucro'].sum().plot.bar(title='Lucro x Ano', color='purple')
plt.xlabel('Ano')
plt.ylabel('Receita');

# %%
#Lucro por ano
df.groupby(df['Data Venda'].dt.year)['Lucro'].sum()
# Out:
# Data Venda
# 2008           1,920,077.71
# 2009           1,577,745.38
# Name: Lucro, dtype: float64

# %%
#Selecionando apenas as vendas de 2009
df_2009 = df[df['Data Venda'].dt.year == 2009]

# %%
df_2009.groupby(df_2009['Data Venda'].dt.month)['Lucro'].sum().plot(title='Lucro x Mês', figsize=(12,6))
plt.xlabel('Mês')
plt.ylabel('Lucro');

# %%
df_2009.groupby('Marca')['Lucro'].sum().plot.bar(title='Lucro x Marca', figsize=(12,6))
plt.xlabel('Marca')
plt.ylabel('Lucro')
plt.xticks(rotation='horizontal');

# %%
df_2009.groupby('Classe')['Lucro'].sum().plot.bar(title='Lucro x Classe', figsize=(10,8))
plt.xlabel('Classe')
plt.ylabel('Lucro')
plt.xticks(rotation='horizontal');

# %%
df['Tempo_envio'].describe()
# Out:
# count                 904.00
# mean                    8.54
# std                     3.06
# min                     4.00
# 25%                     6.00
# 50%                     9.00
# 75%                    11.00
# max                    20.00
# Name: Tempo_envio, dtype: float64

# %%
#Grafico de BoxPlot
plt.boxplot(df['Tempo_envio']);

# %%
#Histograma
plt.hist(df['Tempo_envio']);

# %%
#Identificando o Outlier
df[df['Tempo_envio'] == 20]
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
#
#         Custo Unitário       Preço Unitário  Quantidade       Valor Desconto  \
# 0               348.58               758.00           6                 0.00
#
#            Valor Venda                                Produto  \
# 0             4,548.00  Adventure Works Laptop15.4W M1548 Red
#
#         Fabricante            Marca   Classe  Cor                Custo  \
# 0  Adventure Works  Adventure Works  Regular  Red             2,091.48
#
#                  Lucro Tempo Medio  Tempo_envio
# 0             2,456.52     20 days           20

# %%
df.to_csv('df_vendas_novo.csv', index=False)

# %%
df_2009.to_csv('df_vendas_novo_2009.csv', index=False)
